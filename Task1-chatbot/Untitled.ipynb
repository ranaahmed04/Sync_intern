# %%
import json
import nltk
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
with open('data.json') as json_file:
    conversations = json.load(json_file)

df = pd.DataFrame(conversations['conversations'])
df
# Out:
#                                                 input  \
# 0                                                  hi
# 1                                               hello
# 2                                        Fine thanks
# 3                                         how are you
# 4                                                 bye
# 5                                    what's your name
# 6                     What is the weather like today?
# 7                                     Tell me a joke.
# 8                       What's the capital of France?
# 9                                    How old are you?
# 10  Who is the current President of the United Sta...
# 11                       What is the meaning of life?
# 12                    Can you recommend a good movie?
# 13                      I'm in the mood for a comedy.
# 14          What's the tallest mountain in the world?
# 15                   How do I say 'hello' in Spanish?
# 16                              Do you have any pets?
# 17          What's the best way to learn programming?
# 18                    What's the population of China?
# 19                         What's your favorite book?
# 20             Can you help me with my math homework?
# 21             What's the largest ocean in the world?
# 22                How do I take care of a houseplant?
# 23    What's the distance between Earth and the Moon?
# 24                                Tell me a fun fact.
# 25     How long does it take to learn a new language?
# 26                       What are the primary colors?
#
#                                              response
# 0                                              Hello!
# 1                                  Hello, how are you
# 2                                 Happy to hear this
# 3                          I'm doing well, thank you!
# 4                                            Goodbye!
# 5                            You can call me ChatBot.
# 6   I'm sorry, I don't have access to real-time da...
# 7   Sure! Why don't scientists trust atoms? Becaus...
# 8                     The capital of France is Paris.
# 9   I am an AI language model, so I don't have an ...
# 10  As of my knowledge cutoff in September 2021, t...
# 11  The meaning of life is subjective and can vary...
# 12     Of course! What genre are you in the mood for?
# 13  I recommend watching 'The Hangover.' It's a hi...
# 14  Mount Everest is the tallest mountain in the w...
# 15     To say 'hello' in Spanish, you can say 'hola'.
# 16  As an AI, I don't have a physical form, so I d...
# 17  The best way to learn programming is to start ...
# 18  As of my knowledge cutoff in September 2021, t...
# 19  As an AI, I don't have personal preferences, s...
# 20  Of course! Please provide the details of the p...
# 21  The largest ocean in the world is the Pacific ...
# 22  Houseplants generally need watering, adequate ...
# 23  The average distance between Earth and the Moo...
# 24  Sure! Did you know that honey never spoils? Ar...
# 25  The time it takes to learn a new language can ...
# 26  The primary colors in traditional color theory...

# %%
#function to preprocess the text
def preprocess_text(text):
    stop_words = set(nltk.corpus.stopwords.words('english'))

    words = nltk.word_tokenize(text.lower())

    words = [word for word in words if word.isalnum() and word not in stop_words]

    return ' '.join(words)

# %%
preprocessed_inputs = [preprocess_text(conversation['input']) for conversation in conversations['conversations']]

print(preprocessed_inputs)

responses = [conversation['response'] for conversation in conversations['conversations']]


vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(preprocessed_inputs)
# Out:
# ['hi', 'hello', 'fine thanks', '', 'bye', 'name', 'weather like today', 'tell joke', 'capital france', 'old', 'current president united states', 'meaning life', 'recommend good movie', 'mood comedy', 'tallest mountain world', 'say spanish', 'pets', 'best way learn programming', 'population china', 'favorite book', 'help math homework', 'largest ocean world', 'take care houseplant', 'distance earth moon', 'tell fun fact', 'long take learn new language', 'primary colors']

# %%
def classify_text(text):
    preprocessed_input = preprocess_text(text)
    input_vector = vectorizer.transform([preprocessed_input])
    similarity_scores = cosine_similarity(input_vector, tfidf_matrix)
    max_index = np.argmax(similarity_scores)
    if max(similarity_scores.tolist()[0])==0.0:
        return ""
    return responses[max_index]

# %%
Bye_list=['exit', 'see you later','bye','quit','stop','see you later', 'have a nice day']

print("Bot: Hello, I'm Chatbot. How can I help you today?")

while True:
    user_message = input("you: ")
    print("you : "+user_message)

    if user_message.lower() in Bye_list:
        print('Bot: see you later !')
        break

    res=classify_text(user_message) 

    if res=="":
        print("Bot: I'm sorry, I didn't catch that Please try again.")
        continue

    print(f"Bot: {res}")
# Out:
# Bot: Hello, I'm Chatbot. How can I help you today?
# you : hello
# Bot: Hello, how are you
# you : fine thanks
# Bot: Happy to hear this
# you : how are you
# Bot: I'm sorry, I didn't catch that Please try again.
# you : what is your name
# Bot: You can call me ChatBot.
# you :
# Bot: I'm sorry, I didn't catch that Please try again.
# you :
# Bot: I'm sorry, I didn't catch that Please try again.
# you :
# Bot: I'm sorry, I didn't catch that Please try again.
# you :
# Bot: I'm sorry, I didn't catch that Please try again.
# you :
# Bot: I'm sorry, I didn't catch that Please try again.
# you :
# Bot: I'm sorry, I didn't catch that Please try again.
# you : bye
# Bot: see you later !
